# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, desc, sum, avg
# Initialize
spark = SparkSession.builder.appName("SparkCompleteNotes").getOrCreate()
# Create Base DataFrame

data = [
    (1, "Alice", "Engineering", 75000, 25),
    (2, "Bob", "Marketing", 60000, 30),
    (3, "Charlie", "Engineering", 80000, 35),
    (4, "David", "Sales", 65000, 28),
    (5, "Eve", "Marketing", 70000, 32),
    (6, "Aish", "Engineering" , 50000 , 35),
    (7, "Joy" , "Marketing" , 60000 , 42),
    (8 , "Sam" , "Sales" , 70000, 56),
    (9 , "Ram" , "Engineering", 60000 , 45),
    (10, "Rohit" , "Marketing" , 30000, 57), 
    (11, "Aditya" , "Sales" , 60000, 43), 
    (12, "Aish", "Marketing" , 61000, 34),
    (13, "Ajay", "Sales" , 62000, 42),
    (14, "Cherry" , "HR", 65000, 65),
    (15, "Furry", "Sales", 45000, 63),
    (16, "Derry" , "Enginering" , 65000, 54),
    (17, "Gargi", "Sales" , 65000, 60),
    (18, "Ben",  "Engineering" , 87000, 44),
    (19 , "Henry" , "HR", 76000, 76),
    (20, "Kite", "Sales", 88000, 32)
]
columns = ["Id", "Name", "Department", "Salary", "Age"]
df = spark.createDataFrame(data, columns);
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/13 04:40:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/13 04:40:09 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
dfSelect = df.select("Name","Department","Salary")

# %%
dfSelect.show()
# Out:
# 26/06/13 04:40:22 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# +-------+-----------+------+
# |   Name| Department|Salary|
# +-------+-----------+------+
# |  Alice|Engineering| 75000|
# |    Bob|  Marketing| 60000|
# |Charlie|Engineering| 80000|
# |  David|      Sales| 65000|
# |    Eve|  Marketing| 70000|
# +-------+-----------+------+

# %%
df_filter=df.filter(col("Salary")>65000)

# %%
df_filter.show()
# Out:
# +---+-------+-----------+------+---+
# | Id|   Name| Department|Salary|Age|
# +---+-------+-----------+------+---+
# |  1|  Alice|Engineering| 75000| 25|
# |  3|Charlie|Engineering| 80000| 35|
# |  5|    Eve|  Marketing| 70000| 32|
# +---+-------+-----------+------+---+

# %%
df_withColumn=df.withColumn("Bonus" , col("Salary")*0.10)
df_withColumn.show()
# Out:
# +---+-------+-----------+------+---+------+
# | Id|   Name| Department|Salary|Age| Bonus|
# +---+-------+-----------+------+---+------+
# |  1|  Alice|Engineering| 75000| 25|7500.0|
# |  2|    Bob|  Marketing| 60000| 30|6000.0|
# |  3|Charlie|Engineering| 80000| 35|8000.0|
# |  4|  David|      Sales| 65000| 28|6500.0|
# |  5|    Eve|  Marketing| 70000| 32|7000.0|
# +---+-------+-----------+------+---+------+

# %%
df.write.mode("overwrite").csv("output/employeesTable",header=True)

# %%
df.toPandas().to_csv(
    "output/employees123.csv",
    index=False
)

# %%
df.createOrReplaceTempView("employees")
res=spark.sql("""Select * from employees where Salary > 70000""").show()
# Out:
# +---+-------+-----------+------+---+
# | Id|   Name| Department|Salary|Age|
# +---+-------+-----------+------+---+
# |  1|  Alice|Engineering| 75000| 25|
# |  3|Charlie|Engineering| 80000| 35|
# +---+-------+-----------+------+---+
